# %%
import requests
from bs4 import BeautifulSoup
import csv


date=input('please enter date in the following format MM/DD/YYYY : ')
page=requests.get(f"https://www.yallakora.com/match-center/?date={date}#")

# %%
def main(page):
    src=page.content
    soup=BeautifulSoup(src,'lxml')
    
    matches_detail = []
    championchimps = soup.find_all("div",{'class':'matchCard'})
    
    
    def get_match_info(championchimps):
        
        championchimp_title=championchimps.contents[1].find('h2').text.strip()
        print(championchimp_title)
        
        all_matches=championchimps.find_all('div',{'class':'item'}).text.strip()
        print(all_matches)
        
        n_matches=len(all_matches)
       
        
        
    get_match_info(championchimps[3])
    
main(page)
# Out:
# الدوري الإنجليزي
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 23
#      17         n_matches=len(all_matches)
#      21     get_match_info(championchimps[3])
# ---> 23 main(page)
#
# Cell In[10], line 21, in main(page)
#      15     print(all_matches)
#      17     n_matches=len(all_matches)
# ---> 21 get_match_info(championchimps[3])
#
# Cell In[10], line 14, in main.<locals>.get_match_info(championchimps)
#      11 championchimp_title=championchimps.contents[1].find('h2').text.strip()
#      12 print(championchimp_title)
# ---> 14 all_matches=championchimps.find_all('div',{'class':'item'}).text.strip()
#      15 print(all_matches)
#      17 n_matches=len(all_matches)
#
# File c:\Users\NIPEAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
def main(page):
    src=page.content
    soup=BeautifulSoup(src,'lxml')
    
    matches_detail = []
    championchimps = soup.find_all("div",{'class':'matchCard'})
    
    for league in championchimps:
        
        championchimp_title=league.contents[1].find('h2').text.strip()
        print(championchimp_title)
        
        all_matches=league.find_all('div',{'class':'item'})
        # print(all_matches)
        
        n_matches=len(all_matches)
        print(n_matches)

        
        for i in range(n_matches):
            #get teams names
            team_a=all_matches[i].find('div',{'class':'teamA'}).text.strip()
            team_b=all_matches[i].find('div',{'class':'teamB'}).text.strip()
            #get score of the match
            match_result=all_matches[i].find('div',{'class':'MResult'}).find_all('span',{'class':'score'})
            
            print(f"{team_a} {match_result[0].text.strip()}-{match_result[1].text.strip()} {team_b}")
            
            #get match time
            match_time=all_matches[i].find('span',{'class':'time'}).text.strip()
            print(f"{match_time}")
        
    
    
main(page)
# Out:
# كأس إنتركونتينينتال
# 1
# العين 6-2 أوكلاند سيتي
# 19:00
# دوري أبطال أفريقيا
# 5
# ساجرادا اسبيرانسا 3-1 إينوجو رينجرز
# 17:30
# ميلو إف سي 2-1 ستاد أبيدجان
# 19:00
# اسكو كارا 0-1 دجوليبا
# 19:00
# الجيش الملكي 2-0 المريخ
# 21:00
# الهلال السوداني 1-0 سان بيدرو
# 22:00
# الكونفيدرالية الإفريقية
# 10
# سيمبا 3-1 أهلي طرابلس
# 16:00
# ديناموز 0-1 أورابا يونايتد
# 16:00
# فيتا كلوب 1-1 ستيلينبوش
# 17:00
# سانت إيلوا لوبوبو 1-2 نادي برافوس دو ماكيس
# 17:30
# أوتوهو 2-1 بلاك بولز
# 17:30
# أنيمبــــا 0-0 ايتوال فيلانتي
# 18:00
# المصري 3-2 الهلال الليبي
# 19:00
# أسيك أبيدجـــــان 2-0 إي إس سي كارا
# 19:00
# دياراف داكار 3-0 راسينج كلوب ابيديجان
# 20:00
# اتحاد العاصمة 2-0 الملعب التونسي
# 20:00
# الدوري الإنجليزي
# 2
# برايتون 2-2 نوتينجهام فورست
# 16:00
# مانشستر سيتي 2-2 أرسنال
# 18:30
# الدوري الإسباني
# 4
# خيتافي 1-1 ديبورتيفو ليجانيس
# 15:00
# أتلتيك بلباو 3-1 سيلتا فيجو
# 17:15
# فياريال 1-5 برشلونة
# 19:30
# رايو فاييكانو 1-1 اتلتيكو مدريد
# 22:00
# الدوري الفرنسي
# 5
# موناكو 3-1 لوهافر
# 16:00
# بريست 2-0 تولوز
# 18:00
# أنجيه 1-1 نانت
# 18:00
# مونبيليه 3-2 اوكسير
# 18:00
# ليون 2-3 مارسيليا
# 21:45
# الدوري الألماني
# 3
# باير ليفركوزن 4-3 فولفسبورج
# 16:30
# شتوتجارت 5-1 بروسيا دورتموند
# 18:30
# سانت باولي 0-0 لايبزيج
# 20:30
# الدوري الإيطالي
# 4
# فيورنتينا 2-1 لاتسيو
# 13:30
# مونزا 1-2 بولونيا
# 16:00
# روما 3-0 أودينيزي
# 19:00
# إنتر ميلان 1-2 ميلان
# 21:45
# الدوري التركي
# 4
# ريزه سبور 0-1 سامسون سبور
# 17:00
# قاسم باشا 0-0 انطاليا سبور
# 17:00
# بشكتاش 2-1 ايوبسبور
# 20:00
# أضنة دمير سبور 0-2 ألانيا سبور
# 20:00
# الدوري البرتغالي
# 3
# جل فيسنتي 1-1 كازا بيا
# 17:30
# فيرنسي 0-1 أروكا
# 20:00
# سبورتينج لشبونة 3-0 اي في اس فوتبول
# 22:30
# الدوري المغربي
# 2
# النادي المكناسي 0-2 الشباب الرياضي السالمي
# 18:00
# شباب المحمدية 1-2 أولمبيك آسفي
# 20:00
# الدوري الإماراتي
# 2
# شباب الأهلي 5-4 الوحـــدة
# 16:30
# العروبة 1-2 خورفكان
# 16:30
# دوري نجوم قطر
# 3
# الريان 0-2 الوكرة
# 18:00
# نادي قطر 1-3 الغرافة
# 20:00
# الأهلي القطري 3-3 العربي
# 20:00
# الدوري التونسي
# 1
# الافريقي التونسي 2-0 شبيبة العمران
# 18:30

# %%
import requests
from bs4 import BeautifulSoup
import csv
from googletrans import Translator  # Google API to translate
import mysql.connector
from datetime import datetime



global date
def main(page):
    date = input('Please enter date in the following format MM/DD/YYYY: ')
    page = requests.get(f"https://www.yallakora.com/match-center/?date={date}#")
    
    translator = Translator()
    src = page.content
    soup = BeautifulSoup(src, 'lxml')
    
    matches_detail = []
    championchimps = soup.find_all("div", {'class': 'matchCard'})
    
    def get_match_info(championchimps):
        championchimp_title = translator.translate(championchimps.contents[1].find('h2').text.strip(), src='ar', dest='en').text
        print(championchimp_title)
        
        all_matches = championchimps.find_all('div', {'class': 'item'})
        n_matches = len(all_matches)
        print(n_matches)

        for i in range(n_matches):
            # Get teams' names
            team_a = translator.translate(all_matches[i].find('div', {'class': 'teamA'}).text.strip(), src='ar', dest='en').text
            team_b = translator.translate(all_matches[i].find('div', {'class': 'teamB'}).text.strip(), src='ar', dest='en').text
            
            # Get score of the match
            match_result = all_matches[i].find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
            print(f"{team_a} {match_result[0].text.strip()} - {match_result[1].text.strip()} {team_b}")
            
            # Get match time
            match_time = all_matches[i].find('span', {'class': 'time'}).text.strip()
            print(f"{match_time}")
            
            # Add match info to matches_detail
            matches_detail.append({
                'tourment': championchimp_title,
                'team A': team_a,
                'score': f"{match_result[0].text.strip()} - {match_result[1].text.strip()}",
                'team B': team_b,
                'match time': match_time,
            })
        
    for league in championchimps:
        get_match_info(league)
    
    print(matches_detail)
    
    keys = matches_detail[0].keys()
    try:
        with open('C:/Users/NIPEAL/OneDrive/Desktop/projectss/py_project_githubs/web_scraping/ws_football_web/matches.csv', 'w', newline='', encoding='utf-8') as f:
            dict_writer = csv.DictWriter(f, keys)
            dict_writer.writeheader()
            dict_writer.writerows(matches_detail)
            print("CSV file created")
    except Exception as e:
        print(f'CSV file creation failed: {e}')
    
    to_database(matches_detail)   

def to_database(match_detail):
    s=date.split('/')
    dates=f"{s[2]}-{s[0]}-{s[1]}"
    
    db_name = input("Enter your database to connect: ")
    conn = mysql.connector.connect(host='localhost', user='root', password='root', database=db_name, use_pure=True)
    cursor = conn.cursor()
    table_name = input("Enter table name: ")
    
    # Create table if it does not exist
    cursor.execute(f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            tourment VARCHAR(255),
            teamA VARCHAR(255),
            score VARCHAR(10),
            teamB VARCHAR(255),
            matchTime TIME,
            match_date DATE
        )
    """)

    for match in match_detail:
        # Use parameterized query to prevent SQL injection and syntax errors
        cursor.execute(f'''
            INSERT INTO {table_name} (tourment, teamA, score, teamB, matchTime, match_date)
            VALUES (%s, %s, %s, %s, %s, %s)
        ''', (match['tourment'], match['team A'], match['score'], match['team B'], match['match time'],dates))
    
    conn.commit()
    conn.close()

main(page)
# Out:
# Egyptian Super Cup
# 2
# Pyramids 1 - 1 Zamalek
# 16:05
# Al -Ahly 2 - 1 Ceramica Cleopatra
# 20:00
# English Premier League
# 2
# Wolverhampton 1 - 2 Manchester City
# 16:00
# Liverpool 2 - 1 Chelsea
# 18:30
# Spanish league
# 4
# Mallorca 1 - 0 Rayo Valicano
# 15:00
# Atletico Madrid 3 - 1 Deportivo Leganes
# 17:15
# Villarreal 1 - 1 Getafe
# 19:30
# Barcelona 5 - 1 Seville
# 22:00
# German league
# 2
# Holstein Keel 0 - 2 Union Berlin
# 16:30
# Wolfsburg 2 - 4 Werder Bremen
# 18:30
# The second section league-a
# 5
# Ismailia Electricity 2 - 0 Mansoura
# 15:30
# Interior 0 - 1 Suez team
# 15:30
# Abu Qir for fertilizer 1 - 2 Wadi Degla
# 15:30
# Telecom Egypt 2 - 0 Mahalla municipality
# 15:30
# Railway 0 - 0 Raya Al -Riyadi
# 15:30
# French league
# 5
# Luhafer 0 - 4 Lyon
# 16:00
# Oxir 2 - 1 Rims
# 18:00
# Toulouse 1 - 1 Anguian
# 18:00
# Nantes 1 - 1 Nice
# 18:00
# Montpellier 0 - 5 Marseille
# 21:45
# Italian league
# 5
# Empoli 0 - 1 Napoli
# 13:30
# Venizia 0 - 2 Atalanta
# 16:00
# Lichy 0 - 6 Fiorentina
# 16:00
# Cagliari 3 - 2 Turin
# 19:00
# Rome 0 - 1 Inter Milan
# 21:45
# Saudi League
# 3
# Conquest 1 - 1 Eternity
# 17:45
# Groove 0 - 1 Riyadh
# 18:20
# Agreement 2 - 3 Arabism
# 21:00
# Turkish League
# 4
# Sivaspor 3 - 2 Hatay Spor
# 13:30
# Besiktas 2 - 0 Konya Sport
# 16:00
# Samson Sport 2 - 2 Fenerbah
# 19:00
# Alani Spur 1 - 2 Qasim Pasha
# 19:00
# Moroccan League
# 1
# Olympic Safi 2 - 3 Tangier Union
# 20:00
# Tunisian League
# 5
# Gafsa caravans 0 - 2 Olympic Olympic
# 17:00
# Esperance Jurisi 1 - 0 Esperance Sports
# 17:00
# The coastal star 0 - 1 Tunisian stadium
# 17:00
# Fabis 1 - 2 Suleiman Al -Riyadi
# 17:00
# Etihad bin Qirdan 2 - 0 Tataouine Union
# 17:00
# [{'tourment': 'Egyptian Super Cup', 'team A': 'Pyramids', 'score': '1 - 1', 'team B': 'Zamalek', 'match time': '16:05'}, {'tourment': 'Egyptian Super Cup', 'team A': 'Al -Ahly', 'score': '2 - 1', 'team B': 'Ceramica Cleopatra', 'match time': '20:00'}, {'tourment': 'English Premier League', 'team A': 'Wolverhampton', 'score': '1 - 2', 'team B': 'Manchester City', 'match time': '16:00'}, {'tourment': 'English Premier League', 'team A': 'Liverpool', 'score': '2 - 1', 'team B': 'Chelsea', 'match time': '18:30'}, {'tourment': 'Spanish league', 'team A': 'Mallorca', 'score': '1 - 0', 'team B': 'Rayo Valicano', 'match time': '15:00'}, {'tourment': 'Spanish league', 'team A': 'Atletico Madrid', 'score': '3 - 1', 'team B': 'Deportivo Leganes', 'match time': '17:15'}, {'tourment': 'Spanish league', 'team A': 'Villarreal', 'score': '1 - 1', 'team B': 'Getafe', 'match time': '19:30'}, {'tourment': 'Spanish league', 'team A': 'Barcelona', 'score': '5 - 1', 'team B': 'Seville', 'match time': '22:00'}, {'tourment': 'German league', 'team A': 'Holstein Keel', 'score': '0 - 2', 'team B': 'Union Berlin', 'match time': '16:30'}, {'tourment': 'German league', 'team A': 'Wolfsburg', 'score': '2 - 4', 'team B': 'Werder Bremen', 'match time': '18:30'}, {'tourment': 'The second section league-a', 'team A': 'Ismailia Electricity', 'score': '2 - 0', 'team B': 'Mansoura', 'match time': '15:30'}, {'tourment': 'The second section league-a', 'team A': 'Interior', 'score': '0 - 1', 'team B': 'Suez team', 'match time': '15:30'}, {'tourment': 'The second section league-a', 'team A': 'Abu Qir for fertilizer', 'score': '1 - 2', 'team B': 'Wadi Degla', 'match time': '15:30'}, {'tourment': 'The second section league-a', 'team A': 'Telecom Egypt', 'score': '2 - 0', 'team B': 'Mahalla municipality', 'match time': '15:30'}, {'tourment': 'The second section league-a', 'team A': 'Railway', 'score': '0 - 0', 'team B': 'Raya Al -Riyadi', 'match time': '15:30'}, {'tourment': 'French league', 'team A': 'Luhafer', 'score': '0 - 4', 'team B': 'Lyon', 'match time': '16:00'}, {'tourment': 'French league', 'team A': 'Oxir', 'score': '2 - 1', 'team B': 'Rims', 'match time': '18:00'}, {'tourment': 'French league', 'team A': 'Toulouse', 'score': '1 - 1', 'team B': 'Anguian', 'match time': '18:00'}, {'tourment': 'French league', 'team A': 'Nantes', 'score': '1 - 1', 'team B': 'Nice', 'match time': '18:00'}, {'tourment': 'French league', 'team A': 'Montpellier', 'score': '0 - 5', 'team B': 'Marseille', 'match time': '21:45'}, {'tourment': 'Italian league', 'team A': 'Empoli', 'score': '0 - 1', 'team B': 'Napoli', 'match time': '13:30'}, {'tourment': 'Italian league', 'team A': 'Venizia', 'score': '0 - 2', 'team B': 'Atalanta', 'match time': '16:00'}, {'tourment': 'Italian league', 'team A': 'Lichy', 'score': '0 - 6', 'team B': 'Fiorentina', 'match time': '16:00'}, {'tourment': 'Italian league', 'team A': 'Cagliari', 'score': '3 - 2', 'team B': 'Turin', 'match time': '19:00'}, {'tourment': 'Italian league', 'team A': 'Rome', 'score': '0 - 1', 'team B': 'Inter Milan', 'match time': '21:45'}, {'tourment': 'Saudi League', 'team A': 'Conquest', 'score': '1 - 1', 'team B': 'Eternity', 'match time': '17:45'}, {'tourment': 'Saudi League', 'team A': 'Groove', 'score': '0 - 1', 'team B': 'Riyadh', 'match time': '18:20'}, {'tourment': 'Saudi League', 'team A': 'Agreement', 'score': '2 - 3', 'team B': 'Arabism', 'match time': '21:00'}, {'tourment': 'Turkish League', 'team A': 'Sivaspor', 'score': '3 - 2', 'team B': 'Hatay Spor', 'match time': '13:30'}, {'tourment': 'Turkish League', 'team A': 'Besiktas', 'score': '2 - 0', 'team B': 'Konya Sport', 'match time': '16:00'}, {'tourment': 'Turkish League', 'team A': 'Samson Sport', 'score': '2 - 2', 'team B': 'Fenerbah', 'match time': '19:00'}, {'tourment': 'Turkish League', 'team A': 'Alani Spur', 'score': '1 - 2', 'team B': 'Qasim Pasha', 'match time': '19:00'}, {'tourment': 'Moroccan League', 'team A': 'Olympic Safi', 'score': '2 - 3', 'team B':  ...
# CSV file created

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 to_database(matches_detail)
#
# NameError: name 'matches_detail' is not defined

# %%
g="10/20/2024"
s=g.split('/')
s=f"{s[2]}-{s[0]}-{s[1]}"
s
# Out:
# '2024-10-20'
